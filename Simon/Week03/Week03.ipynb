# %% [markdown]
# # Part 1: Getting the dataset
#
# I've downloaded the CSV-file from SF OpenData homepage. And below I'd import it to python.

# %%
import pandas as pd

with open("SFPD_Incidents_-_from_1_January_2003.csv", 'rb') as f:
    df = pd.read_csv("SFPD_Incidents_-_from_1_January_2003.csv")

# %%
df.head(100)
# Out:
#     IncidntNum           Category  \
# 0    150060275       NON-CRIMINAL
# 1    150098210            ROBBERY
# 2    150098210            ASSAULT
# 3    150098210    SECONDARY CODES
# 4    150098226          VANDALISM
# 5    150098232       NON-CRIMINAL
# 6    150098248    SECONDARY CODES
# 7    150098248          VANDALISM
# 8    150098254           BURGLARY
# 9    150098260      LARCENY/THEFT
# 10   150098345      LARCENY/THEFT
# 11   150098345      DRUG/NARCOTIC
# 12   150098345      DRUG/NARCOTIC
# 13   150098345           WARRANTS
# 14   150098367            ROBBERY
# 15   150098373      VEHICLE THEFT
# 16   150098373       NON-CRIMINAL
# 17   150098389           WARRANTS
# 18   150098395      LARCENY/THEFT
# 19   150098408     OTHER OFFENSES
# 20   150098414            ROBBERY
# 21   150098414            ROBBERY
# 22   150098414            ASSAULT
# 23   150098414            ASSAULT
# 24   150098420            ROBBERY
# 25   150098420            ASSAULT
# 26   150098420        WEAPON LAWS
# 27   150098436       NON-CRIMINAL
# 28   150098442     OTHER OFFENSES
# 29   150098458            ASSAULT
# ..         ...                ...
# 70   150098765     SUSPICIOUS OCC
# 71   150098771            ROBBERY
# 72   150098787    SECONDARY CODES
# 73   150098787     SUSPICIOUS OCC
# 74   150098812      LARCENY/THEFT
# 75   150098828      LARCENY/THEFT
# 76   150098834           BURGLARY
# 77   150098840     OTHER OFFENSES
# 78   150098856       NON-CRIMINAL
# 79   150098862            ASSAULT
# 80   150098862      LARCENY/THEFT
# 81   150098884      LARCENY/THEFT
# 82   150098890            ASSAULT
# 83   150098903      LARCENY/THEFT
# 84   150098919  RECOVERED VEHICLE
# 85   150098919     OTHER OFFENSES
# 86   150098919     OTHER OFFENSES
# 87   150098925           WARRANTS
# 88   150098931     MISSING PERSON
# 89   150098947        DRUNKENNESS
# 90   150098947            ASSAULT
# 91   150098947     OTHER OFFENSES
# 92   150098947          VANDALISM
# 93   150098953            ASSAULT
# 94   150098969            ROBBERY
# 95   150098975       NON-CRIMINAL
# 96   150098981      LARCENY/THEFT
# 97   150098997            ROBBERY
# 98   150098997      DRUG/NARCOTIC
# 99   150099008           WARRANTS
#
#                                              Descript DayOfWeek        Date  \
# 0                                       LOST PROPERTY    Monday  01/19/2015
# 1                               ROBBERY, BODILY FORCE    Sunday  02/01/2015
# 2                AGGRAVATED ASSAULT WITH BODILY FORCE    Sunday  02/01/2015
# 3                                   DOMESTIC VIOLENCE    Sunday  02/01/2015
# 4           MALICIOUS MISCHIEF, VANDALISM OF VEHICLES   Tuesday  01/27/2015
# 5                AIDED CASE -PROPERTY FOR DESTRUCTION    Sunday  02/01/2015
# 6                                   DOMESTIC VIOLENCE  Saturday  01/31/2015
# 7                       MALICIOUS MISCHIEF, VANDALISM  Saturday  01/31/2015
# 8                   BURGLARY OF STORE, UNLAWFUL ENTRY  Saturday  01/31/2015
# 9                             PETTY THEFT SHOPLIFTING  Saturday  01/31/2015
# 10                            PETTY THEFT SHOPLIFTING    Sunday  02/01/2015
# 11                     POSSESSION OF METH-AMPHETAMINE    Sunday  02/01/2015
# 12              POSSESSION OF NARCOTICS PARAPHERNALIA    Sunday  02/01/2015
# 13                                     WARRANT ARREST    Sunday  02/01/2015
# 14                        ROBBERY, ARMED WITH A KNIFE    Sunday  02/01/2015
# 15                                  STOLEN AUTOMOBILE    Sunday  02/01/2015
# 16                                     FOUND PROPERTY    Sunday  02/01/2015
# 17                    ENROUTE TO OUTSIDE JURISDICTION    Sunday  02/01/2015
# 18                       PETTY THEFT FROM LOCKED AUTO    Sunday  02/01/2015
# 19              DRIVERS LICENSE, SUSPENDED OR REVOKED    Sunday  02/01/2015
# 20                   ROBBERY ON THE STREET, STRONGARM    Sunday  02/01/2015
# 21                              ROBBERY, BODILY FORCE    Sunday  02/01/2015
# 22               AGGRAVATED ASSAULT WITH BODILY FORCE    Sunday  02/01/2015
# 23                      BATTERY WITH SERIOUS INJURIES    Sunday  02/01/2015
# 24             ATTEMPTED ROBBERY WITH A DEADLY WEAPON    Sunday  02/01/2015
# 25               AGGRAVATED ASSAULT WITH BODILY FORCE    Sunday  02/01/2015
# 26                            POSS OF TEAR GAS WEAPON    Sunday  02/01/2015
# 27                                      LOST PROPERTY    Sunday  02/01/2015
# 28                                  TRAFFIC VIOLATION    Sunday  02/01/2015
# 29                        BATTERY OF A POLICE OFFICER    Sunday  02/01/2015
# ..                                                ...       ...         ...
# 70                            INVESTIGATIVE DETENTION    Sunday  02/01/2015
# 71                   ROBBERY ON THE STREET, STRONGARM  Thursday  01/29/2015
# 72                                  DOMESTIC VIOLENCE    Sunday  02/01/2015
# 73                              SUSPICIOUS OCCURRENCE    Sunday  02/01/2015
# 74                     PETTY THEFT FROM UNLOCKED AUTO    Friday  01/30/2015
# 75                       GRAND THEFT FROM LOCKED AUTO    Sunday  02/01/2015
# 76                           BURGLARY, UNLAWFUL ENTRY    Friday  01/30/2015
# 77              DRIVERS LICENSE, SUSPENDED OR REVOKED    Sunday  02/01/2015
# 78                                    COURTESY REPORT    Sunday  02/01/2015
# 79                                            BATTERY    Sunday  02/01/2015
# 80                            PETTY THEFT SHOPLIFTING    Sunday  02/01/2015
# 81                       GRAND THEFT FROM LOCKED AUTO    Sunday  02/01/2015
# 82               AGGRAVATED ASSAULT WITH BODILY FORCE    Sunday  02/01/2015
# 83                            GRAND THEFT OF PROPERTY    Sunday  02/01/2015
# 84                           VEHICLE, RECOVERED, AUTO    Sunday  02/01/2015
# 85           CONTRIBUTING TO THE DELINQUENCY OF MINOR    Sunday  02/01/2015
# 86                                  TRAFFIC VIOLATION    Sunday  02/01/2015
# 87                    ENROUTE TO OUTSIDE JURISDICTION    Sunday  02/01/2015
# 88                                      MISSING ADULT  Thursday  01/29/2015
# 89       UNDER INFLUENCE OF ALCOHOL IN A PUBLIC PLACE    Sunday  02/01/2015
# 90              THREATENING SCHOOL OR PUBLIC EMPLOYEE    Sunday  02/01/2015
# 91                                   RESISTING ARREST    Sunday  02/01/2015
# 92          MALICIOUS MISCHIEF, VANDALISM OF VEHICLES    Sunday  02/01/2015
# 93                                            BATTERY    Sunday  02/01/2015
# 94                              ROBBERY, BODILY FORCE    Sunday  02/01/2015
# 95                       AIDED CASE, MENTAL DISTURBED    Sunday  02/01/2015
# 96                        PETTY THEFT FROM A BUILDING    Sunday  02/01/2015
# 97  ATTEMPTED ROBBERY ON THE STREET WITH BODILY FORCE    Sunday  02/01/2015
# 98                            POSSESSION OF MARIJUANA    Sunday  02/01/2015
# 99                                   PROBATION SEARCH    Sunday  02/01/2015
#
#      Time  PdDistrict       Resolution                              Address  \
# 0   14:00     MISSION             NONE                18TH ST / VALENCIA ST
# 1   15:45  TENDERLOIN             NONE          300 Block of LEAVENWORTH ST
# 2   15:45  TENDERLOIN             NONE          300 Block of LEAVENWORTH ST
# 3   15:45  TENDERLOIN             NONE          300 Block of LEAVENWORTH ST
# 4   19:00    NORTHERN             NONE               LOMBARD ST / LAGUNA ST
# 5   16:21    RICHMOND             NONE               400 Block of LOCUST ST
# 6   21:00     BAYVIEW             NONE             700 Block of KIRKWOOD AV
# 7   21:00     BAYVIEW             NONE             700 Block of KIRKWOOD AV
# 8   16:09     CENTRAL             NONE             200 Block of STOCKTON ST
# 9   17:00     CENTRAL             NONE                800 Block of GEARY ST
# 10  14:00     MISSION   ARREST, BOOKED            1700 Block of HARRISON ST
# 11  14:00     MISSION   ARREST, BOOKED            1700 Block of HARRISON ST
# 12  14:00     MISSION   ARREST, BOOKED            1700 Block of HARRISON ST
# 13  14:00     MISSION   ARREST, BOOKED            1700 Block of HARRISON ST
# 14  16:20     MISSION             NONE              2200 Block of MARKET ST
# 15  12:45    NORTHERN             NONE                FRANKLIN ST / TURK ST
# 16  12:45    NORTHERN             NONE                FRANKLIN ST / TURK ST
# 17  16:38     BAYVIEW   ARREST, BOOKED                 3800 Block of 3RD ST
# 18  14:30        PARK             NONE  MARTIN LUTHER KING JR DR / KEZAR DR
# 19  17:25     BAYVIEW   ARREST, BOOKED              NEWCOMB AV / MENDELL ST
# 20  17:05     CENTRAL   ARREST, BOOKED                PACIFIC AV / GRANT AV
# 21  17:05     CENTRAL   ARREST, BOOKED                PACIFIC AV / GRANT AV
# 22  17:05     CENTRAL   ARREST, BOOKED                PACIFIC AV / GRANT AV
# 23  17:05     CENTRAL   ARREST, BOOKED                PACIFIC AV / GRANT AV
# 24  17:10  TENDERLOIN   ARREST, BOOKED                400 Block of ELLIS ST
# 25  17:10  TENDERLOIN   ARREST, BOOKED                400 Block of ELLIS ST
# 26  17:10  TENDERLOIN   ARREST, BOOKED                400 Block of ELLIS ST
# 27  17:00     BAYVIEW             NONE                     20TH ST / 3RD ST
# 28  17:38  TENDERLOIN   ARREST, BOOKED                   MARKET ST / 8TH ST
# 29  16:56     MISSION   ARREST, BOOKED             2000 Block of MISSION ST
# ..    ...         ...              ...                                  ...
# 70  19:06    SOUTHERN             NONE               MISSION ST / DUBOCE AV
# 71  03:00     MISSION             NONE                 16TH ST / MISSION ST
# 72  18:17     BAYVIEW             NONE               BACON ST / HAMILTON ST
# 13  15009834563010
# 14  15009836703072
# 15  15009837307021
# 16  15009837372000
# 17  15009838962050
# 18  15009839506243
# 19  15009840865016
# 20  15009841403014
# 21  15009841403074
# 22  15009841404014
# 23  15009841404136
# 24  15009842003473
# 25  15009842004014
# 26  15009842012130
# 27  15009843671000
# 28  15009844265015
# 29  15009845804154
# ..             ...
# 70  15009876564085
# 71  15009877103014
# 72  15009878715200
# 73  15009878764070
# 74  15009881206223
# 75  15009882806244
# 76  15009883405073
# 77  15009884065016
# 78  15009885668030
# 79  15009886204134
# 80  15009886206361
# 81  15009888406244
# 82  15009889004014
# 83  15009890306374
# 84  15009891907041
# 85  15009891915030
# 86  15009891965015
# 87  15009892562050
# 88  15009893174000
# 89  15009894719090
# 90  15009894726210
# 91  15009894727170
# 92  15009894728160
# 93  15009895304134
# 94  15009896903074
# 95  15009897564020
# 96  15009898106303
# 97  15009899703414
# 98  15009899716010
# 99  15009900862071
#
# [100 rows x 13 columns]

# %% [markdown]
# # Part 2: Working with data
#
# **Exercise: The types of crime and their popularity over time. The first field we'll dig into is the column "Category".**

# %%
#Finding the number of different crime types
SetCrimeType = set(df['Category'])
NumCrimeType = len(SetCrimeType)
print "There are %d different crime categories." % NumCrimeType
# Out:
# There are 39 different crime categories.

# %%
#Counting each crime incident per crime type
CrimeDict = {}
for Type in SetCrimeType:
    counter = 0
    for incident in df['Category']:
        if incident == Type:
            counter += 1
    CrimeDict[Type] = counter
    
#Creating a pandas dataframe from the dictionary
df2 = pd.DataFrame.from_dict(CrimeDict, orient = 'index')

#Finding the most and least frequent crime
print "The most frequent crime is:" 
print df2.nlargest(1, 0)

print "The least frequent crime is:" 
print df2.nsmallest(1, 0)
# Out:
# The most frequent crime is:
#                     0
# LARCENY/THEFT  422170
# The least frequent crime is:
#        0
# TREA  13

# %%
import matplotlib.pyplot as plt
#Sorting the dataframe by value
df2 = pd.DataFrame.sort_values(df2, 0)

bar_width = 0.5
index = range(len(df2[0]))
plt.bar(index, df2[0], bar_width)


plt.xticks([x+(bar_width/2) for x in index], df2.index, rotation='vertical')
plt.xlabel('x')
plt.ylabel('Count')
plt.title('Number of incidents per crime')

plt.show()

# %%
#Create a dictionary with year (key) and number of crimes (values)
YearList = []
for i in df['Date']:
    YearList.append(int( i.split("/")[-1]))

YearDict = {}
                        
for i in set(YearList):
    counter = 0
    for x in YearList:
        if i == x:
            counter += 1
    YearDict[i] = counter

# %%
#Creating a dataframe for the counted crimes
df3 = pd.DataFrame.from_dict(YearDict, orient = 'index')

df3 = pd.DataFrame.sort_index(df3)
df3 = df3.drop(2017)
df3.tail()
# Out:
#            0
# 2012  140854
# 2013  152806
# 2014  150131
# 2015  156543
# 2016  149502

# %%
#Calculating the average number of crimes per year
print "Average crimes per year:"
print sum(df3[0])/len(df3[0])
# Out:
# Average crimes per year:
# 143730

# %%
#Creating bar charts for focus crimes:
focuscrimes = set(['WEAPON LAWS', 'PROSTITUTION', 'DRIVING UNDER THE INFLUENCE', 'ROBBERY', 'BURGLARY', 'ASSAULT', 'DRUNKENNESS', 'DRUG/NARCOTIC', 'TRESPASS', 'LARCENY/THEFT', 'VANDALISM', 'VEHICLE THEFT', 'STOLEN PROPERTY', 'DISORDERLY CONDUCT'])
                  
print focuscrimes
# Out:
# set(['VEHICLE THEFT', 'DISORDERLY CONDUCT', 'WEAPON LAWS', 'VANDALISM', 'PROSTITUTION', 'DRUG/NARCOTIC', 'TRESPASS', 'ASSAULT', 'DRIVING UNDER THE INFLUENCE', 'DRUNKENNESS', 'ROBBERY', 'BURGLARY', 'STOLEN PROPERTY', 'LARCENY/THEFT'])

# %%
df3.columns = ['Total number of crimes']

# %%
#Adding the years to the original dataframe
df['Year'] = YearList
df.head()
# Out:
#    IncidntNum         Category                                   Descript  \
# 0   150060275     NON-CRIMINAL                              LOST PROPERTY
# 1   150098210          ROBBERY                      ROBBERY, BODILY FORCE
# 2   150098210          ASSAULT       AGGRAVATED ASSAULT WITH BODILY FORCE
# 3   150098210  SECONDARY CODES                          DOMESTIC VIOLENCE
# 4   150098226        VANDALISM  MALICIOUS MISCHIEF, VANDALISM OF VEHICLES
#
#   DayOfWeek        Date   Time  PdDistrict Resolution  \
# 0    Monday  01/19/2015  14:00     MISSION       NONE
# 1    Sunday  02/01/2015  15:45  TENDERLOIN       NONE
# 2    Sunday  02/01/2015  15:45  TENDERLOIN       NONE
# 3    Sunday  02/01/2015  15:45  TENDERLOIN       NONE
# 4   Tuesday  01/27/2015  19:00    NORTHERN       NONE
#
#                        Address           X          Y  \
# 0        18TH ST / VALENCIA ST -122.421582  37.761701
# 1  300 Block of LEAVENWORTH ST -122.414406  37.784191
# 2  300 Block of LEAVENWORTH ST -122.414406  37.784191
# 3  300 Block of LEAVENWORTH ST -122.414406  37.784191
# 4       LOMBARD ST / LAGUNA ST -122.431119  37.800469
#
#                                 Location            PdId  Year
# 0   (37.7617007179518, -122.42158168137)  15006027571000  2015
# 1  (37.7841907151119, -122.414406029855)  15009821003074  2015
# 2  (37.7841907151119, -122.414406029855)  15009821004014  2015
# 3  (37.7841907151119, -122.414406029855)  15009821015200  2015
# 4  (37.8004687042875, -122.431118543788)  15009822628160  2015

# %%
CrimeYearDict = {}
for i in focuscrimes:
    CrimeYearDict[i]= {}
    for year in range(2003, 2017, 1):
        CrimeYearDict[i][year] = 0
    
for index in range(len(df)):
    c = df.get_value(index, 'Category')
    y = df.get_value(index, 'Year')
    if c in focuscrimes and y < 2017:
        CrimeYearDict[c][y] += 1
    
print CrimeYearDict
# Out:
# {'WEAPON LAWS': {2016: 1651, 2003: 1281, 2004: 1252, 2005: 1341, 2006: 1324, 2007: 1318, 2008: 1419, 2009: 1433, 2010: 1349, 2011: 1329, 2012: 1460, 2013: 1535, 2014: 1580, 2015: 1655}, 'ROBBERY': {2016: 3293, 2003: 3204, 2004: 3380, 2005: 3566, 2006: 4131, 2007: 4027, 2008: 4229, 2009: 3578, 2010: 3324, 2011: 3376, 2012: 3955, 2013: 4196, 2014: 3420, 2015: 3759}, 'PROSTITUTION': {2016: 640, 2003: 1952, 2004: 1527, 2005: 1103, 2006: 1290, 2007: 1873, 2008: 1673, 2009: 1468, 2010: 1299, 2011: 1094, 2012: 690, 2013: 692, 2014: 449, 2015: 374
#
#       VANDALISM  PROSTITUTION  DRUG/NARCOTIC  TRESPASS  ASSAULT  \
# 2003       6448          1952           9917      1434    13461
# 2004       6496          1527           9897      1191    12899
# 2005       7013          1103           8533      1034    11601
# 2006       7688          1290           9069      1102    12449
# 2007       7566          1873          10560      1198    12518
#
#       DRIVING UNDER THE INFLUENCE  DRUNKENNESS  ROBBERY  BURGLARY  \
# 2003                          289          662     3204      6047
# 2004                          244          600     3380      6753
# 2005                          196          636     3566      7071
# 2006                          266          703     4131      7004
# 2007                          313          671     4027      5454
#
#       STOLEN PROPERTY  LARCENY/THEFT
# 2003              800          26393
# 2004              641          24505
# 2005              540          25319
# 2006              575          27352
# 2007              527          25770

# %%
#Transposing the df for easier plotting
df4 = df3.transpose()

#plotting the evolution of the focuscrimes
counter = 0
plt.figure(1)
for crime in focuscrimes:
    counter += 1
    plt.subplot(2, 7, counter)
    df4.ix[crime].plot(kind='bar'); plt.axhline(0, color='k')
plt.show()

# %% [markdown]
# **Now I want to look at focuscrimes compared to the time of day**

# %%
#Creating a dictionary for the crime time
CrimeTimeDict = {}
for crime in focuscrimes:
    CrimeTimeDict[crime]= {}
    for time in range(0, 24):
        CrimeTimeDict[crime][time] = 0

for index in range(len(df)):
    crime = df.get_value(index, 'Category')
    time = df.get_value(index, 'Time')
    hr = int( time.split(":")[0] )
    if crime in focuscrimes:
        CrimeTimeDict[crime][hr] += 1
    
print CrimeTimeDict
# Out:
# {'WEAPON LAWS': {0: 1032, 1: 749, 2: 669, 3: 393, 4: 290, 5: 157, 6: 230, 7: 399, 8: 548, 9: 718, 10: 731, 11: 862, 12: 991, 13: 982, 14: 994, 15: 1127, 16: 1197, 17: 1158, 18: 1257, 19: 1157, 20: 1084, 21: 1084, 22: 1159, 23: 1097}, 'ROBBERY': {0: 2803, 1: 2840, 2: 2998, 3: 1809, 4: 1173, 5: 999, 6: 961, 7: 870, 8: 990, 9: 1168, 10: 1326, 11: 1502, 12: 1781, 13: 1924, 14: 2033, 15: 2306, 16: 2546, 17: 2492, 18: 2643, 19: 2832, 20: 3158, 21: 3607, 22: 3570, 23: 3341}, 'PROSTITUTION': {0: 1314, 1: 1020, 2: 750, 3: 517, 4: 454, 5: 571, 6: 514, 7: 265, 8: 148, 9: 158, 10: 189, 11: 208, 12: 443, 13: 325, 14: 286, 15: 209, 16: 270, 17: 575, 18: 1155, 19: 1338, 20: 1067, 21: 1262, 22: 1557, 23: 1568}, 'DRUG/NARCOTIC': {0: 3626, 1: 2195, 2: 1777, 3: 1197, 4: 880, 5: 445, 6: 1286, 7: 2909, 8: 3878, 9: 4555, 10: 5116, 11: 5674, 12: 5891, 13: 7651, 14: 8701, 15: 7986, 16: 8403, 17: 8628, 18: 7696, 19: 6550, 20: 5016, 21: 4722, 22: 5579, 23: 4770}, 'TRESPASS': {0: 517, 1: 372, 2: 404, 3: 331, 4: 235, 5: 492, 6: 1078, 7: 1147, 8: 1063, 9: 959, 10: 937, 11: 883, 12: 962, 13: 908, 14: 800, 15: 881, 16: 812, 17: 834, 18: 780, 19: 704, 20: 662, 21: 659, 22: 
df5.head()
# Out:
#    ASSAULT  BURGLARY  DISORDERLY CONDUCT  DRIVING UNDER THE INFLUENCE  \
# 0     9996      3148                 504                          684
# 1     8587      2037                 374                          623
# 2     7808      2156                 330                          617
# 3     3939      2160                 214                          271
# 4     2466      1930                 151                          103
#
#    DRUG/NARCOTIC  DRUNKENNESS  LARCENY/THEFT  PROSTITUTION  ROBBERY  \
# 0           3626          804          16917          1314     2803
# 1           2195          761          10413          1020     2840
# 2           1777          635           6868           750     2998
# 3           1197          250           4230           517     1809
# 4            880          128           2750           454     1173
#
#    STOLEN PROPERTY  TRESPASS  VANDALISM  VEHICLE THEFT  WEAPON LAWS
# 0              515       517       5994           4503         1032
# 1              370       372       4214           3109          749
# 2              307       404       3980           2462          669
# 3              236       331       2604           1511          393
# 4              210       235       1723           1164          290

# %%
#Transposing the df for easier plotting
df6 = df5.transpose()

#plotting the evolution of the focuscrimes
counter = 0
plt.figure(1)
for crime in focuscrimes:
    counter += 1
    plt.subplot(7, 2, counter)
    df6.ix[crime].plot(kind='bar'); plt.axhline(0, color='k')
    plt.title(crime)
    
plt.subplots_adjust(hspace=.5)
plt.show()

# %% [markdown]
# **I forgot to create a histogram for all the crimes pr hour, so it comes here:**

# %%
TotalCrimeTimeDict = {}
for hr in range(0, 24):
    TotalCrimeTimeDict[hr] = 0

for index in range(len(df)):
    time = df.get_value(index, 'Time')
    hr = int( time.split(":")[0] )
    TotalCrimeTimeDict[hr] += 1
    
print TotalCrimeTimeDict
# Out:
# {0: 103719, 1: 60049, 2: 50352, 3: 32404, 4: 22894, 5: 20339, 6: 30587, 7: 51007, 8: 75672, 9: 81771, 10: 86931, 11: 88618, 12: 120631, 13: 99044, 14: 102423, 15: 109948, 16: 114815, 17: 123971, 18: 128199, 19: 114542, 20: 104345, 21: 100098, 22: 104650, 23: 96856}

# %%
plt.figure(1)
plt.bar(range(len(TotalCrimeTimeDict)), TotalCrimeTimeDict.values(), align='center')
plt.xticks(range(len(TotalCrimeTimeDict)), TotalCrimeTimeDict.keys())
plt.title('Total # of crimes per hour')
plt.show()

# %% [markdown]
# **Exercises: The types of crime and how they take place across San Francisco's police districts.**
#
# * So now we'll be combining information about PdDistrict and Category to explore differences between SF's >neighborhoods. First, simply list the names of SF's 10 police districts.

# %%
#finding the unique district names
districts_temp = df['PdDistrict'].unique()
print districts_temp

#Removing the nan element and converting to list instead of numpy array
districts = []
for i in range(len(districts_temp)-1):
    districts.append(districts_temp[i])
    
print districts
# Out:
# ['MISSION' 'TENDERLOIN' 'NORTHERN' 'RICHMOND' 'BAYVIEW' 'CENTRAL' 'PARK'
#  'TARAVAL' 'SOUTHERN' 'INGLESIDE' nan]
# ['MISSION', 'TENDERLOIN', 'NORTHERN', 'RICHMOND', 'BAYVIEW', 'CENTRAL', 'PARK', 'TARAVAL', 'SOUTHERN', 'INGLESIDE']

# %% [markdown]
# * Which has the most crimes? Which has the most focus crimes?

# %%
TotalCrimeDistrictDict = {}
for district in districts:
    TotalCrimeDistrictDict[district] = 0
    
for district in df['PdDistrict']:
    if district in districts:
        TotalCrimeDistrictDict[district] += 1
    

MaxCrimeDistrict = max(TotalCrimeDistrictDict, key=TotalCrimeDistrictDict.get)
print 'The district with most crimes is: %s' % MaxCrimeDistrict
print 'With %d as the total number of crimes since 2003. \n' % TotalCrimeDistrictDict[MaxCrimeDistrict]

TotalFocusCrimeDistrictDict = {}
for district in districts:
    TotalFocusCrimeDistrictDict[district] = 0
    
for index in range(len(df)):
    if df.get_value(index, 'Category') in focuscrimes:
        if df.get_value(index, 'PdDistrict') in districts:
            TotalFocusCrimeDistrictDict[df.get_value(index, 'PdDistrict')] += 1

MaxFocusCrimeDistrict = max(TotalFocusCrimeDistrictDict, key=TotalFocusCrimeDistrictDict.get)
print 'The district with most focus crimes is: %s' % MaxFocusCrimeDistrict
print 'With %d as the total number of focus crimes since 2003.' % TotalFocusCrimeDistrictDict[MaxFocusCrimeDistrict]
# Out:
# The district with most crimes is: SOUTHERN
# With 364516 as the total number of crimes since 2003.
#
# The district with most focus crimes is: SOUTHERN
# With 208888 as the total number of focus crimes since 2003.

# %% [markdown]
# **Exercises: The types of crime and how they take place across San Francisco's police districts.**
#
# First, we need to calculate the relative probabilities of seeing each type of crime in the dataset as a whole. > That's simply a normalized version of this plot. Let's call it P(crime).

# %%
CrimeTotal = float(sum(df2[0]))
CrimeNormalized = []

for i in df2[0]:
    CrimeNormalized.append(i/CrimeTotal)
    
df2['Normalized'] = CrimeNormalized

bar_width = 0.5
index = range(len(df2[0]))
plt.bar(index, df2['Normalized'], bar_width)


plt.xticks([x+(bar_width/2) for x in index], df2.index, rotation='vertical')
plt.xlabel('x')
plt.ylabel('Ratio')
plt.title('Ratio of incidents per crime')

plt.show()

# %% [markdown]
# Next, we calculate that same probability distribution but for each PD district, let's call that P(crime|district).

# %%
#Creating an empty dictionary
DistrictFocusCountDict = {}
for district in districts:
    DistrictFocusCountDict[district]={}
    for crime in focuscrimes:
        DistrictFocusCountDict[district][crime] = 0
        
#counting each instance of the crime
for index in df[]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-37b20b8151d2> in <module>()
# ----> 1 CrimeDistrictDict
#
# NameError: name 'CrimeDistrictDict' is not defined

# %% [markdown]
# # Part 4: A little bit of plotting

# %%
#Setting bounding box
max_lat = 37.833972
min_lat = 37.713972
max_lon = -122.461297
min_lon = -122.401297

bbox = BoundingBox(north=max_lat, west=min_lon, south=min_lat, east=max_lon)
geoplotlib.set_bbox(bbox)

# %%
lon = []
lat = []
for index in range(len(df)):
    lon.append(int(df.get_value(index, 'X')))
    lat.append(int(df.get_value(index, 'Y')))

# %%
import geoplotlib

geoplotlib.kde(lon, lat)
geoplotlib.inline(width=900)
geoplotlib.show()
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Simon\Anaconda2\lib\site-packages\geoplotlib\__init__.py", line 32, in _runapp
#     app.start()
#   File "C:\Users\Simon\Anaconda2\lib\site-packages\geoplotlib\core.py", line 367, in start
#     l.invalidate(self.proj)
#   File "C:\Users\Simon\Anaconda2\lib\site-packages\geoplotlib\layers.py", line 734, in invalidate
#     xv, yv = proj.lonlat_to_screen(self.values['lon'], self.values['lat'])
# TypeError: list indices must be integers, not str
