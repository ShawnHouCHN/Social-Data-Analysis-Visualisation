# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("NYPD_Motor_Vehicle_Collisions.csv", low_memory=False)

# %%
df.head()
# Out:
#          DATE  TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  03/28/2017  0:00      BRONX    10466  40.894600 -73.861206
# 1  03/28/2017  0:00   BROOKLYN    11218  40.654080 -73.977610
# 2  03/28/2017  0:00   BROOKLYN    11235  40.583847 -73.940590
# 3  03/28/2017  0:00  MANHATTAN    10019  40.762770 -73.975590
# 4  03/28/2017  0:00     QUEENS    11429  40.713715 -73.731440
#
#                  LOCATION                    ON STREET NAME CROSS STREET NAME  \
# 0   (40.8946, -73.861206)                               NaN               NaN
# 1   (40.65408, -73.97761)  18 STREET                            SEELEY STREET
# 2  (40.583847, -73.94059)                               NaN               NaN
# 3   (40.76277, -73.97559)                               NaN               NaN
# 4  (40.713715, -73.73144)  222 STREET                              101 AVENUE
#
#                             OFF STREET NAME         ...          \
# ...

# %%
df_weather = pd.read_csv("NY_weather_data.csv")

# %%
df_weather.head()
# Out:
#    Unnamed: 0 Average Humidity Cooling Degree Days        Date Dew Point  \
# 0         0.0               71                   0  2012/01/01         4
# 1         1.0               56                   0  2012/01/02        -7
# 2         2.0               54                   0  2012/01/03       -13
# 3         3.0               47                   0  2012/01/04       -16
# 4         4.0               50                   0  2012/01/05        -8
#
#   Events Growing Degree Days Heating Degree Days Max Gust Speed  \
# 0   Rain                 NaN                  18             35
# 1    NaN                 NaN                  23             52
# 2    NaN                 NaN                  41             48
# 3    NaN                 NaN                  45             35
# 4    NaN                 NaN                  31             35
#
#   Max Temperature            ...             Since 1 July heating degree days  \
# ...

# %%
df['DATE'] = pd.to_datetime(df.DATE)

# %%
df['Date'] = df['DATE'].dt.strftime('%Y/%m/%d')

# %%
df.head()
# Out:
#         DATE  TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0 2017-03-28  0:00      BRONX    10466  40.894600 -73.861206
# 1 2017-03-28  0:00   BROOKLYN    11218  40.654080 -73.977610
# 2 2017-03-28  0:00   BROOKLYN    11235  40.583847 -73.940590
# 3 2017-03-28  0:00  MANHATTAN    10019  40.762770 -73.975590
# 4 2017-03-28  0:00     QUEENS    11429  40.713715 -73.731440
#
#                  LOCATION                    ON STREET NAME CROSS STREET NAME  \
# 0   (40.8946, -73.861206)                               NaN               NaN
# 1   (40.65408, -73.97761)  18 STREET                            SEELEY STREET
# 2  (40.583847, -73.94059)                               NaN               NaN
# 3   (40.76277, -73.97559)                               NaN               NaN
# 4  (40.713715, -73.73144)  222 STREET                              101 AVENUE
#
#                             OFF STREET NAME     ...      \
# 0  600       EAST 233 STREET                    ...
# ...

# %%
df_comb = pd.merge(df, df_weather, on='Date')

# %%
df_comb
# Out:
#               DATE   TIME        BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0       2017-03-28   0:00          BRONX    10466  40.894600 -73.861206
# 1       2017-03-28   0:00       BROOKLYN    11218  40.654080 -73.977610
# 2       2017-03-28   0:00       BROOKLYN    11235  40.583847 -73.940590
# 3       2017-03-28   0:00      MANHATTAN    10019  40.762770 -73.975590
# 4       2017-03-28   0:00         QUEENS    11429  40.713715 -73.731440
# 5       2017-03-28   0:00            NaN      NaN  40.803585 -73.915520
# 6       2017-03-28   0:00            NaN      NaN  40.835194 -73.874054
# 7       2017-03-28   0:01       BROOKLYN    11234  40.622400 -73.936646
# 8       2017-03-28   0:01            NaN      NaN  40.660824 -73.950650
# 9       2017-03-28   0:25            NaN      NaN  40.757366 -73.955740
# 10      2017-03-28   0:37            NaN      NaN  40.723648 -73.991030
# 11      2017-03-28  10:00          BRONX    10462  40.847687 -73.868180
# ...

# %%
df_comb[df_comb['Date'] == '2012/07/01']
# Out:
#               DATE   TIME        BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 1004637 2012-07-01   0:21            NaN      NaN        NaN        NaN
# 1004638 2012-07-01  17:00            NaN      NaN  40.853709 -73.871857
# 1004639 2012-07-01   5:00            NaN      NaN  40.537332 -74.189127
# 1004640 2012-07-01   0:05      MANHATTAN    10036  40.762127 -73.997387
# 1004641 2012-07-01   0:05            NaN      NaN  40.697753 -73.813916
# 1004642 2012-07-01   0:10       BROOKLYN    11223  40.588868 -73.972745
# 1004643 2012-07-01   0:10            NaN      NaN  40.733610 -73.923840
# 1004644 2012-07-01   0:20       BROOKLYN    11215  40.677406 -73.983048
# 1004645 2012-07-01   0:22          BRONX    10451  40.824188 -73.913840
# 1004646 2012-07-01   0:23       BROOKLYN    11234  40.607179 -73.916414
# 1004647 2012-07-01   0:25         QUEENS    11375  40.732979 -73.844348
# 1004648 2012-07-01   0:30       BROOKLYN    11233  40.670118 -73.922467
# ...

# %%
df_comb.columns
# Out:
# Index(['DATE', 'TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE', 'LONGITUDE',
#        'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME', 'OFF STREET NAME',
#        'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED',
#        'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED',
#        'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED',
#        'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED',
#        'CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2',
#        'CONTRIBUTING FACTOR VEHICLE 3', 'CONTRIBUTING FACTOR VEHICLE 4',
#        'CONTRIBUTING FACTOR VEHICLE 5', 'UNIQUE KEY', 'VEHICLE TYPE CODE 1',
#        'VEHICLE TYPE CODE 2', 'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4',
#        'VEHICLE TYPE CODE 5', 'Date', 'Unnamed: 0', 'Average Humidity',
#        'Cooling Degree Days', 'Dew Point', 'Events', 'Growing Degree Days',
#        'Heating Degree Days', 'Max Gust Speed', 'Max Temperature',
# ...

# %%
df_comb.to_csv("NYPD_Motor_Vehicle_Collisions_all_data.csv", index=False)

# %%
columns_to_keep = ['Date', 'TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE', 'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2', 'UNIQUE KEY', 'VEHICLE TYPE CODE 1','VEHICLE TYPE CODE 2', 'Average Humidity', 'Dew Point', 'Events', 'Max Gust Speed', 'Max Temperature', 'Max Wind Speed', 'Maximum Humidity', 'Mean Temperature', 'Min Temperature', 'Minimum Humidity', 'Precipitation', 'Sea Level Pressure', 'Snow', 'Snow Depth', 'Visibility', 'Wind Speed']

# %%
df_reduced = df_comb[columns_to_keep]

# %%
df_reduced.to_csv("NYPD_Motor_Vehicle_Collisions_reduced_data.csv", index=False)
